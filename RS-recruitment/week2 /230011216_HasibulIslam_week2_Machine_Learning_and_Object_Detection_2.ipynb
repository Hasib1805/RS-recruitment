# %% [markdown]
# <a href="https://colab.research.google.com/github/Hasib1805/RS-recruitment/blob/main/RS-recruitment/week2%20/230011216_HasibulIslam_week2_Machine_Learning_and_Object_Detection_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.5/112.6 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
from google.colab import userdata

rf = Roboflow(api_key=userdata.get("api_key"))
project = rf.workspace("birds-d0caz").project("birds-ytaav")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 91.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 133.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Birds-1 in yolov8:: 100%|██████████| 1614/1614 [00:00<00:00, 8817.39it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(
    data=f'{dataset.location}/data.yaml',
    epochs=50,
    name='bird_detection',
    save=True,
    plots=True,
    verbose=True
)
# Out:
# ...
# Ultralytics 8.3.217 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/bird_detection/weights/best.pt")

results = model.predict(
    source="Birds-1/test/images",
    save=True
)
# Out:
# image 1/33 /content/Birds-1/test/images/-117-_jpg.rf.79beda834304c9d649a63e6f8e48f055.jpg: 640x640 1 Robin, 5.7ms
# image 2/33 /content/Birds-1/test/images/-15-_jpg.rf.aef79611ad55e09b5e535face407035a.jpg: 640x640 1 Robin, 6.0ms
# image 3/33 /content/Birds-1/test/images/-16-_jpg.rf.7c150a4273f420c4357f48bbb0ea61f5.jpg: 640x640 1 Robin, 5.7ms
# image 4/33 /content/Birds-1/test/images/-17-_jpg.rf.cb170faae3c1e4532bbb9a207333b7c4.jpg: 640x640 1 Robin, 5.5ms
# image 5/33 /content/Birds-1/test/images/-26-_jpg.rf.329f1478a33987e046bdac16ae91a834.jpg: 640x640 1 Crow, 5.5ms
# image 6/33 /content/Birds-1/test/images/-27-_jpg.rf.74c7f4d79fe54c5ddeba3399d0ddaf83.jpg: 640x640 1 Robin, 6.5ms
# image 7/33 /content/Birds-1/test/images/-29-_jpg.rf.b3badfc111eb3e4a3a5932ab15149593.jpg: 640x640 1 Robin, 5.6ms
# image 8/33 /content/Birds-1/test/images/-35-_jpg.rf.a9238c4ac7e5524dc79ea810318c3633.jpg: 640x640 1 Robin, 5.8ms
# ...
